# %%
problem = "Pendulum-v1"
env = gym.make(problem)

num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity=100000, batch_size=64):
        # Number of "experiences" to store at max
        self.buffer_capacity = buffer_capacity
        # Num of tuples to train on.
        self.batch_size = batch_size

        # Its tells us num of times record() was called.
        self.buffer_counter = 0

        # Instead of list of tuples as the exp.replay concept go
        # We use different np.arrays for each tuple element
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))

    # Takes (s,a,r,s') obervation tuple as input
    def record(self, obs_tuple):
        # Set index to zero if buffer_capacity is exceeded,
        # replacing old records
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    @tf.function
    def update(
        self,
        state_batch,
        action_batch,
        reward_batch,
        next_state_batch,
    ):
        # Training and updating Actor & Critic networks.
        # See Pseudo Code.
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            y = reward_batch + gamma * target_critic(
                [next_state_batch, target_actions], training=True
            )
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = tf.math.reduce_mean(tf.math.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            # Used `-value` as we want to maximize the value given
            # by the critic for our actions
            actor_loss = -tf.math.reduce_mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    # We compute the loss and update parameters
    def learn(self):
        # Get sampling range
        record_range = min(self.buffer_counter, self.buffer_capacity)
        # Randomly sample indices
        batch_indices = np.random.choice(record_range, self.batch_size)

        # Convert to tensors
        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])

        self.update(state_batch, action_batch, reward_batch, next_state_batch)

# %%
# This update target parameters slowly
# Based on rate `tau`, which is much less than one.
@tf.function
def update_target(target_weights, weights, tau):
    for a, b in zip(target_weights, weights):
        a.assign(b * tau + a * (1 - tau))

def get_actor():
    # Initialize weights between -3e-3 and 3-e3
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)

    inputs = layers.Input(shape=(num_states,))
    out = layers.Dense(256, activation="relu")(inputs)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1, activation="tanh", kernel_initializer=last_init)(out)

    # Our upper bound is 2.0 for Pendulum.
    outputs = outputs * upper_bound
    model = tf.keras.Model(inputs, outputs)
    return model


def get_critic():
    # State as input
    state_input = layers.Input(shape=(num_states))
    state_out = layers.Dense(16, activation="relu")(state_input)
    state_out = layers.Dense(32, activation="relu")(state_out)

    # Action as input
    action_input = layers.Input(shape=(num_actions))
    action_out = layers.Dense(32, activation="relu")(action_input)

    # Both are passed through seperate layer before concatenating
    concat = layers.Concatenate()([state_out, action_out])

    out = layers.Dense(256, activation="relu")(concat)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1)(out)

    # Outputs single value for give state-action
    model = tf.keras.Model([state_input, action_input], outputs)

    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    # Adding noise to action
    sampled_actions = sampled_actions.numpy() + noise

    # We make sure action is within bounds
    legal_action = np.clip(sampled_actions, lower_bound, upper_bound)

    return [np.squeeze(legal_action)]

## Training hyperparameters
std_dev = 0.2
ou_noise = OUActionNoise(mean=np.zeros(1), std_deviation=float(std_dev) * np.ones(1))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_lr = 0.002
actor_lr = 0.001

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 500
# Discount factor for future rewards
gamma = 0.99
# Used to update target networks
tau = 0.005

buffer = Buffer(50000, 64)

# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []

# Takes about 4 min to train
for ep in range(total_episodes):
    prev_state = env.reset()
    episodic_reward = 0

    while True:
        # Uncomment this to see the Actor in action
        # But not in a python notebook.
        # env.render()

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)
        # Recieve state and reward from environment.
        state, reward, done, info = env.step(action)

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        # End this episode when `done` is True
        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)

    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-500:])
    print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    avg_reward_list.append(avg_reward)

# Plotting graph
# Episodes versus Avg. Rewards
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()

# Save the weights
actor_model.save_weights("pendulum_actor.h5")
critic_model.save_weights("pendulum_critic.h5")

target_actor.save_weights("pendulum_target_actor.h5")
target_critic.save_weights("pendulum_target_critic.h5")
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  2.0
# Min Value of Action ->  -2.0
# Episode * 0 * Avg Reward is ==> -1511.8436655908376
# Episode * 1 * Avg Reward is ==> -1569.9275944173628
# Episode * 2 * Avg Reward is ==> -1604.9741400362284
# Episode * 3 * Avg Reward is ==> -1549.4799762174423
# Episode * 4 * Avg Reward is ==> -1544.5839368703641
# Episode * 5 * Avg Reward is ==> -1491.282314526684
# Episode * 6 * Avg Reward is ==> -1502.2525564559292
# Episode * 7 * Avg Reward is ==> -1504.3923497477158
# Episode * 8 * Avg Reward is ==> -1503.678297398782
# Episode * 9 * Avg Reward is ==> -1466.9736956786019
# Episode * 10 * Avg Reward is ==> -1395.113151598591
# Episode * 11 * Avg Reward is ==> -1301.2459020199408
# Episode * 12 * Avg Reward is ==> -1201.4523577073371
# Episode * 13 * Avg Reward is ==> -1146.9834104118625
# Episode * 14 * Avg Reward is ==> -1115.998782576797
# Episode * 15 * Avg Reward is ==> -1097.6276224040928
# Episode * 16 * Avg Reward is ==> -1085.6121266618247
# Episode * 17 * Avg Reward is ==> -1045.7693764053338
# Episode * 18 * Avg Reward is ==> -1010.3850629247846
# Episode * 19 * Avg Reward is ==> -974.0858905056655
# Episode * 20 * Avg Reward is ==> -939.6021423214902
# Episode * 21 * Avg Reward is ==> -913.3051471083877
# Episode * 22 * Avg Reward is ==> -889.0792507494972
# Episode * 23 * Avg Reward is ==> -863.8911102630035
# Episode * 24 * Avg Reward is ==> -829.379351856823
# Episode * 25 * Avg Reward is ==> -815.0308841556955
# Episode * 26 * Avg Reward is ==> -798.7066483227973
# Episode * 27 * Avg Reward is ==> -774.8144125793525
# Episode * 28 * Avg Reward is ==> -759.7948639804971
# Episode * 29 * Avg Reward is ==> -738.6559692621898
# Episode * 30 * Avg Reward is ==> -714.8473952729885
# Episode * 31 * Avg Reward is ==> -696.5589978545117
# Episode * 32 * Avg Reward is ==> -675.5088909279772
# Episode * 33 * Avg Reward is ==> -662.9873234031597
# Episode * 34 * Avg Reward is ==> -647.5838698069168
# Episode * 35 * Avg Reward is ==> -639.9158954062218
# Episode * 36 * Avg Reward is ==> -629.3699228415956
# Episode * 37 * Avg Reward is ==> -616.3078284146633
# Episode * 38 * Avg Reward is ==> -615.1915888928512
# Episode * 39 * Avg Reward is ==> -616.1082797196707
# Episode * 40 * Avg Reward is ==> -604.2922428018596
# Episode * 41 * Avg Reward is ==> -604.3863907486924
# Episode * 42 * Avg Reward is ==> -596.1899343109964
# Episode * 43 * Avg Reward is ==> -590.8081681651697
# Episode * 44 * Avg Reward is ==> -580.6730583982785
# Episode * 45 * Avg Reward is ==> -581.7189132103349
# Episode * 46 * Avg Reward is ==> -572.2180095625257
# Episode * 47 * Avg Reward is ==> -562.9642864045132
# Episode * 48 * Avg Reward is ==> -554.0016200938928
# Episode * 49 * Avg Reward is ==> -548.9087921520336
# Episode * 50 * Avg Reward is ==> -538.2920930574228
# Episode * 51 * Avg Reward is ==> -532.7898065756914
# Episode * 52 * Avg Reward is ==> -529.5261500157418
# Episode * 53 * Avg Reward is ==> -521.9393097602134
# Episode * 54 * Avg Reward is ==> -519.013986000452
# Episode * 55 * Avg Reward is ==> -520.8881749017963
# Episode * 56 * Avg Reward is ==> -518.5518671855849
# Episode * 57 * Avg Reward is ==> -511.93008243083955
# Episode * 58 * Avg Reward is ==> -507.5040652210083
# Episode * 59 * Avg Reward is ==> -507.32669257930297
# Episode * 60 * Avg Reward is ==> -500.9809004644282
# Episode * 61 * Avg Reward is ==> -494.82990793882567
# Episode * 62 * Avg Reward is ==> -491.0154302975654
# Episode * 63 * Avg Reward is ==> -485.48293277816197
# Episode * 64 * Avg Reward is ==> -480.0777367674084
# Episode * 65 * Avg Reward is ==> -474.82810878055125
# Episode * 66 * Avg Reward is ==> -469.5508327524327
# Episode * 67 * Avg Reward is ==> -464.5392872956922
# Episode * 68 * Avg Reward is ==> -459.69215538241895
# Episode * 69 * Avg Reward is ==> -456.5501895145379
# Episode * 70 * Avg Reward is ==> -451.95953365897185
# Episode * 71 * Avg Reward is ==> -448.9706519941689
# Episode * 72 * Avg Reward is ==> -446.2918800113934
# Episode * 73 * Avg Reward is ==> -443.3557758877671
# Episode * 74 * Avg Reward is ==> -439.0716673586171
# Episode * 75 * Avg Reward is ==> -436.7445149734466
# Episode * 76 * Avg Reward is ==> -432.6592693590913
# Episode * 77 * Avg Reward is ==> -428.77336825945076
# Episode * 78 * Avg Reward is ==> -424.8730955971603
# Episode * 79 * Avg Reward is ==> -422.6206978424692
# Episode * 80 * Avg Reward is ==> -418.9077675958417
# Episode * 81 * Avg Reward is ==> -415.24554029761595
# Episode * 82 * Avg Reward is ==> -411.7441696701463
# Episode * 83 * Avg Reward is ==> -408.36025332443717
# Episode * 84 * Avg Reward is ==> -406.3905542075847
# Episode * 85 * Avg Reward is ==> -404.56656225090467
# Episode * 86 * Avg Reward is ==> -402.73143523732057
# Episode * 87 * Avg Reward is ==> -400.8847714286924
# Episode * 88 * Avg Reward is ==> -399.0429733929884
# Episode * 89 * Avg Reward is ==> -396.02411310191997
# Episode * 90 * Avg Reward is ==> -395.2289322126032
# Episode * 91 * Avg Reward is ==> -393.5099468094834
# Episode * 92 * Avg Reward is ==> -390.63602159828463
# Episode * 93 * Avg Reward is ==> -390.3704719971622
# Episode * 94 * Avg Reward is ==> -388.81374413272994
# Episode * 95 * Avg Reward is ==> -387.3338654240018
# Episode * 96 * Avg Reward is ==> -385.80833647191315
# Episode * 97 * Avg Reward is ==> -383.1084430935773
# Episode * 98 * Avg Reward is ==> -383.0557989046892
# Episode * 99 * Avg Reward is ==> -382.96792118405216
# Episode * 100 * Avg Reward is ==> -380.44451172281725
# Episode * 101 * Avg Reward is ==> -381.64390694882735
# Episode * 102 * Avg Reward is ==> -383.97851769787184
# Episode * 103 * Avg Reward is ==> -381.5310841601782
# Episode * 104 * Avg Reward is ==> -379.0335999589341
# Episode * 105 * Avg Reward is ==> -380.2517132074258
# Episode * 106 * Avg Reward is ==> -381.38250183645624
# Episode * 107 * Avg Reward is ==> -379.1099988731145
# Episode * 108 * Avg Reward is ==> -376.86265116303787
# Episode * 109 * Avg Reward is ==> -376.46691219618515
# Episode * 110 * Avg Reward is ==> -374.41365209580476
# Episode * 111 * Avg Reward is ==> -374.0584762085246
# Episode * 112 * Avg Reward is ==> -372.9445303686139
# Episode * 113 * Avg Reward is ==> -372.65206214135566
# Episode * 114 * Avg Reward is ==> -369.4209893712627
# Episode * 115 * Avg Reward is ==> -369.4553704541297
# Episode * 116 * Avg Reward is ==> -369.2037950106314
# Episode * 117 * Avg Reward is ==> -367.1196357464584
# Episode * 118 * Avg Reward is ==> -365.08967792723166
# Episode * 119 * Avg Reward is ==> -362.0692783346364
# Episode * 120 * Avg Reward is ==> -360.060189121096
# Episode * 121 * Avg Reward is ==> -359.8054889407783
# Episode * 122 * Avg Reward is ==> -357.8969212034784
# Episode * 123 * Avg Reward is ==> -356.02368133807084
# Episode * 124 * Avg Reward is ==> -355.0823866166421
# Episode * 125 * Avg Reward is ==> -352.27615273833015
# Episode * 126 * Avg Reward is ==> -351.3745609985212
# Episode * 127 * Avg Reward is ==> -349.63031871236274
# Episode * 128 * Avg Reward is ==> -347.82751972182206
# Episode * 129 * Avg Reward is ==> -347.66372438567777
# Episode * 130 * Avg Reward is ==> -349.6582827670541
# Episode * 131 * Avg Reward is ==> -348.90441148130026
# Episode * 132 * Avg Reward is ==> -348.0266272200383
# Episode * 133 * Avg Reward is ==> -345.448985640163
# Episode * 134 * Avg Reward is ==> -343.76635240365636
# Episode * 135 * Avg Reward is ==> -342.11400150197744
# Episode * 136 * Avg Reward is ==> -339.62316198791206
# Episode * 137 * Avg Reward is ==> -338.0646408958906
# Episode * 138 * Avg Reward is ==> -335.67189990536605
# Episode * 139 * Avg Reward is ==> -334.12730011194554
# Episode * 140 * Avg Reward is ==> -332.64865642959865
# Episode * 141 * Avg Reward is ==> -331.9615674316448
# Episode * 142 * Avg Reward is ==> -332.27984609951545
# Episode * 143 * Avg Reward is ==> -331.72831357431903
# Episode * 144 * Avg Reward is ==> -332.06679166493035
# Episode * 145 * Avg Reward is ==> -330.62514367500495
# Episode * 146 * Avg Reward is ==> -329.89253027531936
# Episode * 147 * Avg Reward is ==> -329.22753628960106
# Episode * 148 * Avg Reward is ==> -328.5725286886878
# Episode * 149 * Avg Reward is ==> -327.1533271930841
# Episode * 150 * Avg Reward is ==> -324.99219179461255
# Episode * 151 * Avg Reward is ==> -324.41415059272634
# Episode * 152 * Avg Reward is ==> -323.9784461265756
# Episode * 153 * Avg Reward is ==> -325.72213514349596
# Episode * 154 * Avg Reward is ==> -326.7701078792223
# Episode * 155 * Avg Reward is ==> -327.04547977390365
# Episode * 156 * Avg Reward is ==> -327.3952757308267
# Episode * 157 * Avg Reward is ==> -326.1376839395696
# Episode * 158 * Avg Reward is ==> -324.9220135977179
# Episode * 159 * Avg Reward is ==> -324.53745908312743
# Episode * 160 * Avg Reward is ==> -323.53093203734375
# Episode * 161 * Avg Reward is ==> -322.30903548707204
# Episode * 162 * Avg Reward is ==> -321.7805366789733
# Episode * 163 * Avg Reward is ==> -319.84390344480687
# Episode * 164 * Avg Reward is ==> -319.3868050637949
# Episode * 165 * Avg Reward is ==> -320.59796828891086
# Episode * 166 * Avg Reward is ==> -319.3587366852023
# Episode * 167 * Avg Reward is ==> -318.90990341817735
# Episode * 168 * Avg Reward is ==> -317.74263893663783
# Episode * 169 * Avg Reward is ==> -317.9983012075637
# Episode * 170 * Avg Reward is ==> -316.89445435941235
# Episode * 171 * Avg Reward is ==> -315.81483979161186
# Episode * 172 * Avg Reward is ==> -314.666265020315
# Episode * 173 * Avg Reward is ==> -314.892571663751
# Episode * 174 * Avg Reward is ==> -315.05936695719083
# Episode * 175 * Avg Reward is ==> -314.5486932827254
# Episode * 176 * Avg Reward is ==> -313.4742823007162
# Episode * 177 * Avg Reward is ==> -313.5388043951325
# Episode * 178 * Avg Reward is ==> -312.50571215397287
# Episode * 179 * Avg Reward is ==> -312.58554221202866
# Episode * 180 * Avg Reward is ==> -311.55546395233796
# Episode * 181 * Avg Reward is ==> -311.18537181922005
# Episode * 182 * Avg Reward is ==> -309.52412996810205
# Episode * 183 * Avg Reward is ==> -308.5343994245323
# Episode * 184 * Avg Reward is ==> -307.5710462268071
# Episode * 185 * Avg Reward is ==> -306.61007296611876
# Episode * 186 * Avg Reward is ==> -306.8927432253905
# Episode * 187 * Avg Reward is ==> -305.8772456747759
# Episode * 188 * Avg Reward is ==> -304.9300519811697
# Episode * 189 * Avg Reward is ==> -304.6523327773354
# Episode * 190 * Avg Reward is ==> -303.77765959488124
# Episode * 191 * Avg Reward is ==> -304.04104802317994
# Episode * 192 * Avg Reward is ==> -303.7868411540367
# Episode * 193 * Avg Reward is ==> -303.4887977855934
# Episode * 194 * Avg Reward is ==> -303.81940350670794
# Episode * 195 * Avg Reward is ==> -302.8849558720866
# Episode * 196 * Avg Reward is ==> -303.16714397749575
# Episode * 197 * Avg Reward is ==> -302.23436127248397
# Episode * 198 * Avg Reward is ==> -301.8838879566066
# Episode * 199 * Avg Reward is ==> -301.01357251777563
# Episode * 200 * Avg Reward is ==> -299.55763031707164
# Episode * 201 * Avg Reward is ==> -298.1010349750828
# Episode * 202 * Avg Reward is ==> -298.3511963228016
# Episode * 203 * Avg Reward is ==> -298.06060208249215
# Episode * 204 * Avg Reward is ==> -297.8225629210248
# Episode * 205 * Avg Reward is ==> -297.00344747559564
# Episode * 206 * Avg Reward is ==> -296.19725992611626
# Episode * 207 * Avg Reward is ==> -294.85687556317805
# Episode * 208 * Avg Reward is ==> -294.71281278774006
# Episode * 209 * Avg Reward is ==> -295.1464181407286
# Episode * 210 * Avg Reward is ==> -294.9240460056356
# Episode * 211 * Avg Reward is ==> -295.4661186839042
# Episode * 212 * Avg Reward is ==> -295.78691408084205
# Episode * 213 * Avg Reward is ==> -295.0401328780655
# Episode * 214 * Avg Reward is ==> -294.2655818908351
# Episode * 215 * Avg Reward is ==> -293.4712066575614
# Episode * 216 * Avg Reward is ==> -292.68221355602503
# Episode * 217 * Avg Reward is ==> -291.92950159791064
# Episode * 218 * Avg Reward is ==> -291.24108742740225
# Episode * 219 * Avg Reward is ==> -290.46921411703954
# Episode * 220 * Avg Reward is ==> -289.7039151358889
# Episode * 221 * Avg Reward is ==> -288.96960917207304
# Episode * 222 * Avg Reward is ==> -288.22170370053766
# Episode * 223 * Avg Reward is ==> -287.97308359280106
# Episode * 224 * Avg Reward is ==> -287.20748377959455
# Episode * 225 * Avg Reward is ==> -287.00860566246706
# Episode * 226 * Avg Reward is ==> -285.7627357135675
# Episode * 227 * Avg Reward is ==> -285.08023864299014
# Episode * 228 * Avg Reward is ==> -284.3699596108132
# Episode * 229 * Avg Reward is ==> -283.6804114450359
# Episode * 230 * Avg Reward is ==> -283.44712939346476
# Episode * 231 * Avg Reward is ==> -283.28875528233914
# Episode * 232 * Avg Reward is ==> -282.5857554155768
# Episode * 233 * Avg Reward is ==> -281.9259860215465
# Episode * 234 * Avg Reward is ==> -281.2567126047569
# Episode * 235 * Avg Reward is ==> -280.56779828625923
# Episode * 236 * Avg Reward is ==> -280.4071374541985
# Episode * 237 * Avg Reward is ==> -279.7861989583331
# Episode * 238 * Avg Reward is ==> -279.6226238532509
# Episode * 239 * Avg Reward is ==> -279.44691799213155
# Episode * 240 * Avg Reward is ==> -279.6862838764909
# Episode * 241 * Avg Reward is ==> -279.4990293012358
# Episode * 242 * Avg Reward is ==> -278.8631274254628
# Episode * 243 * Avg Reward is ==> -278.7207127580988
# Episode * 244 * Avg Reward is ==> -278.10780169111996
# Episode * 245 * Avg Reward is ==> -276.99087681219163
# Episode * 246 * Avg Reward is ==> -277.2546812951393
# Episode * 247 * Avg Reward is ==> -277.5929131524679
# Episode * 248 * Avg Reward is ==> -276.49927028874566
# Episode * 249 * Avg Reward is ==> -275.91160836467367
# Episode * 250 * Avg Reward is ==> -275.3620662832613
# Episode * 251 * Avg Reward is ==> -275.21643686569183
# Episode * 252 * Avg Reward is ==> -274.68512022490785
# Episode * 253 * Avg Reward is ==> -274.1160629897299
# Episode * 254 * Avg Reward is ==> -274.3265919909984
# Episode * 255 * Avg Reward is ==> -273.7685180114549
# Episode * 256 * Avg Reward is ==> -273.180331836495
# Episode * 257 * Avg Reward is ==> -273.05085943104007
# Episode * 258 * Avg Reward is ==> -272.4952157743637
# Episode * 259 * Avg Reward is ==> -271.91619278533335
# Episode * 260 * Avg Reward is ==> -271.78565595633114
# Episode * 261 * Avg Reward is ==> -271.20329592220037
# Episode * 262 * Avg Reward is ==> -270.6509696302719
# Episode * 263 * Avg Reward is ==> -270.10929074503474
# Episode * 264 * Avg Reward is ==> -269.6136599147575
# Episode * 265 * Avg Reward is ==> -269.5645297587354
# Episode * 266 * Avg Reward is ==> -269.4527010511461
# Episode * 267 * Avg Reward is ==> -268.93606517273395
# Episode * 268 * Avg Reward is ==> -268.38991925755244
# Episode * 269 * Avg Reward is ==> -268.2553648632397
# Episode * 270 * Avg Reward is ==> -267.70742342255056
# Episode * 271 * Avg Reward is ==> -266.7364272155336
# Episode * 272 * Avg Reward is ==> -266.2057093111049
# Episode * 273 * Avg Reward is ==> -265.72028326034865
# Episode * 274 * Avg Reward is ==> -266.0057414384115
# Episode * 275 * Avg Reward is ==> -265.93698705243327
# Episode * 276 * Avg Reward is ==> -264.99044798528087
# Episode * 277 * Avg Reward is ==> -264.86554429458243
# Episode * 278 * Avg Reward is ==> -264.7842016362896
# Episode * 279 * Avg Reward is ==> -264.3139706848697
# Episode * 280 * Avg Reward is ==> -263.84715713917336
# Episode * 281 * Avg Reward is ==> -263.8247332706654
# Episode * 282 * Avg Reward is ==> -263.80334907362203
# Episode * 283 * Avg Reward is ==> -263.3360413084959
# Episode * 284 * Avg Reward is ==> -263.64760743571026
# Episode * 285 * Avg Reward is ==> -263.19523526426565
# Episode * 286 * Avg Reward is ==> -263.20423001942396
# Episode * 287 * Avg Reward is ==> -263.612977688384
# Episode * 288 * Avg Reward is ==> -264.2963320988335
# Episode * 289 * Avg Reward is ==> -263.81064211109396
# Episode * 290 * Avg Reward is ==> -263.7125758710946
# Episode * 291 * Avg Reward is ==> -263.27227652001653
# Episode * 292 * Avg Reward is ==> -262.80809091090526
# Episode * 293 * Avg Reward is ==> -262.7797949102465
# Episode * 294 * Avg Reward is ==> -262.3218581722741
# Episode * 295 * Avg Reward is ==> -261.86799895515315
# Episode * 296 * Avg Reward is ==> -261.83087609836844
# Episode * 297 * Avg Reward is ==> -260.9669707582537
# Episode * 298 * Avg Reward is ==> -260.10296585334453
# Episode * 299 * Avg Reward is ==> -259.6614318880686
# Episode * 300 * Avg Reward is ==> -259.2250359299756
# Episode * 301 * Avg Reward is ==> -258.37727385962665
# Episode * 302 * Avg Reward is ==> -257.92166761166357
# Episode * 303 * Avg Reward is ==> -257.0857832676675
# Episode * 304 * Avg Reward is ==> -256.67091184974436
# Episode * 305 * Avg Reward is ==> -256.22065716980745
# Episode * 306 * Avg Reward is ==> -255.8024370321155
# Episode * 307 * Avg Reward is ==> -255.34293824069064
# Episode * 308 * Avg Reward is ==> -254.90978038348393
# Episode * 309 * Avg Reward is ==> -258.90548126016455
# Episode * 310 * Avg Reward is ==> -258.8224462816338
# Episode * 311 * Avg Reward is ==> -258.78130773911425
# Episode * 312 * Avg Reward is ==> -258.69983682680174
# Episode * 313 * Avg Reward is ==> -257.88220063821166
# Episode * 314 * Avg Reward is ==> -257.45441124317824
# Episode * 315 * Avg Reward is ==> -257.4188928160745
# Episode * 316 * Avg Reward is ==> -256.9790836478071
# Episode * 317 * Avg Reward is ==> -256.56497497464676
# Episode * 318 * Avg Reward is ==> -255.76607920626142
# Episode * 319 * Avg Reward is ==> -254.97284259776137
# Episode * 320 * Avg Reward is ==> -254.92052250549068
# Episode * 321 * Avg Reward is ==> -254.49010425050412
# Episode * 322 * Avg Reward is ==> -254.7689155364723
# Episode * 323 * Avg Reward is ==> -253.98883007423137
# Episode * 324 * Avg Reward is ==> -253.9119696041707
# Episode * 325 * Avg Reward is ==> -253.52232734268208
# Episode * 326 * Avg Reward is ==> -253.1174052542174
# Episode * 327 * Avg Reward is ==> -252.71435725887724
# Episode * 328 * Avg Reward is ==> -251.9515886719728
# Episode * 329 * Avg Reward is ==> -251.92763175975958
# Episode * 330 * Avg Reward is ==> -251.52909508024774
# Episode * 331 * Avg Reward is ==> -251.49321797689055
# Episode * 332 * Avg Reward is ==> -251.11180981719954
# Episode * 333 * Avg Reward is ==> -251.05447779847543
# Episode * 334 * Avg Reward is ==> -250.6487383835897
# Episode * 335 * Avg Reward is ==> -250.91256978920606
# Episode * 336 * Avg Reward is ==> -250.84096369520836
# Episode * 337 * Avg Reward is ==> -250.48151156766508
# Episode * 338 * Avg Reward is ==> -249.74648490304344
# Episode * 339 * Avg Reward is ==> -249.36642646779586
# Episode * 340 * Avg Reward is ==> -249.29943190334495
# Episode * 341 * Avg Reward is ==> -249.24939722269414
# Episode * 342 * Avg Reward is ==> -248.88869521830318
# Episode * 343 * Avg Reward is ==> -250.83119411218206
# Episode * 344 * Avg Reward is ==> -250.77997365697487
# Episode * 345 * Avg Reward is ==> -250.42900678194545
# Episode * 346 * Avg Reward is ==> -250.05084950755486
# Episode * 347 * Avg Reward is ==> -249.33757506097655
# Episode * 348 * Avg Reward is ==> -249.2993355505647
# Episode * 349 * Avg Reward is ==> -249.27098411016715
# Episode * 350 * Avg Reward is ==> -248.56917904515683
# Episode * 351 * Avg Reward is ==> -248.53086627890707
# Episode * 352 * Avg Reward is ==> -248.82960985498553
# Episode * 353 * Avg Reward is ==> -248.45480419195076
# Episode * 354 * Avg Reward is ==> -248.39997271726466
# Episode * 355 * Avg Reward is ==> -248.04044495185607
# Episode * 356 * Avg Reward is ==> -248.00606699797933
# Episode * 357 * Avg Reward is ==> -247.9715934269605
# Episode * 358 * Avg Reward is ==> -247.28612026340184
# Episode * 359 * Avg Reward is ==> -247.299900708179
# Episode * 360 * Avg Reward is ==> -247.26905320119604
# Episode * 361 * Avg Reward is ==> -247.2077428663577
# Episode * 362 * Avg Reward is ==> -246.85459175516178
# Episode * 363 * Avg Reward is ==> -247.141635716816
# Episode * 364 * Avg Reward is ==> -246.77746873495116
# Episode * 365 * Avg Reward is ==> -246.45239268629206
# Episode * 366 * Avg Reward is ==> -246.11657927693912
# Episode * 367 * Avg Reward is ==> -245.45646268485436
# Episode * 368 * Avg Reward is ==> -245.11883438951148
# Episode * 369 * Avg Reward is ==> -244.7951167584352
# Episode * 370 * Avg Reward is ==> -244.46543908640058
# Episode * 371 * Avg Reward is ==> -244.43397017901827
# Episode * 372 * Avg Reward is ==> -244.40035584674493
# Episode * 373 * Avg Reward is ==> -244.0792611920004
# Episode * 374 * Avg Reward is ==> -244.0600638520699
# Episode * 375 * Avg Reward is ==> -243.41578243152128
# Episode * 376 * Avg Reward is ==> -243.1047566251796
# Episode * 377 * Avg Reward is ==> -242.7929211590367
# Episode * 378 * Avg Reward is ==> -242.4889126571905
# Episode * 379 * Avg Reward is ==> -242.17785619887732
# Episode * 380 * Avg Reward is ==> -241.55550156679712
# Episode * 381 * Avg Reward is ==> -241.82542317810655
# Episode * 382 * Avg Reward is ==> -244.0072867004545
# Episode * 383 * Avg Reward is ==> -243.6958268633763
# Episode * 384 * Avg Reward is ==> -243.6866511950789
# Episode * 385 * Avg Reward is ==> -243.3947732664312
# Episode * 386 * Avg Reward is ==> -243.08918512546722
# Episode * 387 * Avg Reward is ==> -242.76769123737333
# Episode * 388 * Avg Reward is ==> -242.45400793323245
# Episode * 389 * Avg Reward is ==> -242.1734075618359
# Episode * 390 * Avg Reward is ==> -241.8938208142861
# Episode * 391 * Avg Reward is ==> -241.88507286847246
# Episode * 392 * Avg Reward is ==> -241.5757727717418
# Episode * 393 * Avg Reward is ==> -241.60978048022724
# Episode * 394 * Avg Reward is ==> -241.00209603399028
# Episode * 395 * Avg Reward is ==> -240.9998190654721
# Episode * 396 * Avg Reward is ==> -240.39824053503057
# Episode * 397 * Avg Reward is ==> -240.09583136902614
# Episode * 398 * Avg Reward is ==> -239.7929469500107
# Episode * 399 * Avg Reward is ==> -239.8051954731044
# Episode * 400 * Avg Reward is ==> -239.79088695148397
# Episode * 401 * Avg Reward is ==> -239.48254842887442
# Episode * 402 * Avg Reward is ==> -238.89953559490417
# Episode * 403 * Avg Reward is ==> -238.60445744382832
# Episode * 404 * Avg Reward is ==> -238.3164886798116
# Episode * 405 * Avg Reward is ==> -237.73243262002907
# Episode * 406 * Avg Reward is ==> -237.7283211939807
# Episode * 407 * Avg Reward is ==> -237.1486580902404
# Episode * 408 * Avg Reward is ==> -237.1672662558701
# Episode * 409 * Avg Reward is ==> -236.87704841378144
# Episode * 410 * Avg Reward is ==> -236.60372848300466
# Episode * 411 * Avg Reward is ==> -236.32453680611317
# Episode * 412 * Avg Reward is ==> -236.33117225585815
# Episode * 413 * Avg Reward is ==> -236.57477980348688
# Episode * 414 * Avg Reward is ==> -236.58903238370704
# Episode * 415 * Avg Reward is ==> -236.91070798205035
# Episode * 416 * Avg Reward is ==> -236.94888541348155
# Episode * 417 * Avg Reward is ==> -236.68509164996934
# Episode * 418 * Avg Reward is ==> -236.67856258651932
# Episode * 419 * Avg Reward is ==> -236.66862120722521
# Episode * 420 * Avg Reward is ==> -236.11120482877325
# Episode * 421 * Avg Reward is ==> -235.55863110048213
# Episode * 422 * Avg Reward is ==> -235.54783266595072
# Episode * 423 * Avg Reward is ==> -235.796760316372
# Episode * 424 * Avg Reward is ==> -235.53354228814462
# Episode * 425 * Avg Reward is ==> -235.50857308132962
# Episode * 426 * Avg Reward is ==> -235.4851372324057
# Episode * 427 * Avg Reward is ==> -235.47931102190117
# Episode * 428 * Avg Reward is ==> -235.53069227271817
# Episode * 429 * Avg Reward is ==> -236.14628327620497
# Episode * 430 * Avg Reward is ==> -235.88274217507555
# Episode * 431 * Avg Reward is ==> -235.61363282826872
# Episode * 432 * Avg Reward is ==> -235.81710065531664
# Episode * 433 * Avg Reward is ==> -235.27981686891422
# Episode * 434 * Avg Reward is ==> -235.25880782822168
# Episode * 435 * Avg Reward is ==> -235.01294018727302
# Episode * 436 * Avg Reward is ==> -235.0351757445582
# Episode * 437 * Avg Reward is ==> -234.50329072636538
# Episode * 438 * Avg Reward is ==> -234.23760447160396
# Episode * 439 * Avg Reward is ==> -233.70778018565596
# Episode * 440 * Avg Reward is ==> -233.976094894568
# Episode * 441 * Avg Reward is ==> -233.73711462784823
# Episode * 442 * Avg Reward is ==> -234.1306035169111
# Episode * 443 * Avg Reward is ==> -235.3017081318666
# Episode * 444 * Avg Reward is ==> -236.2207340670747
# Episode * 445 * Avg Reward is ==> -236.55347208222352
# Episode * 446 * Avg Reward is ==> -236.87719506241908
# Episode * 447 * Avg Reward is ==> -236.87922582300664
# Episode * 448 * Avg Reward is ==> -237.15340073943563
# Episode * 449 * Avg Reward is ==> -237.12983651780007
# Episode * 450 * Avg Reward is ==> -236.60714634686158
# Episode * 451 * Avg Reward is ==> -236.81493804501378
# Episode * 452 * Avg Reward is ==> -236.8052971041239
# Episode * 453 * Avg Reward is ==> -236.56592300610117
# Episode * 454 * Avg Reward is ==> -236.306483735837
# Episode * 455 * Avg Reward is ==> -236.30501740954927
# Episode * 456 * Avg Reward is ==> -236.0476533335259
# Episode * 457 * Avg Reward is ==> -235.81465648912794
# Episode * 458 * Avg Reward is ==> -236.11214065307132
# Episode * 459 * Avg Reward is ==> -236.68692050208932
# Episode * 460 * Avg Reward is ==> -236.88859284232407
# Episode * 461 * Avg Reward is ==> -237.09835485074407
# Episode * 462 * Avg Reward is ==> -236.83682307387883
# Episode * 463 * Avg Reward is ==> -236.32944045622372
# Episode * 464 * Avg Reward is ==> -236.5788098024044
# Episode * 465 * Avg Reward is ==> -236.59072833988017
# Episode * 466 * Avg Reward is ==> -236.8175614557608
# Episode * 467 * Avg Reward is ==> -236.570348432642
# Episode * 468 * Avg Reward is ==> -236.83042124317814
# Episode * 469 * Avg Reward is ==> -236.59007554170478
# Episode * 470 * Avg Reward is ==> -236.09037187060267
# Episode * 471 * Avg Reward is ==> -235.59371377634668
# Episode * 472 * Avg Reward is ==> -235.58691169188222
# Episode * 473 * Avg Reward is ==> -235.35774658204627
# Episode * 474 * Avg Reward is ==> -234.87088714620742
# Episode * 475 * Avg Reward is ==> -234.62766456590293
# Episode * 476 * Avg Reward is ==> -234.38744537972903
# Episode * 477 * Avg Reward is ==> -234.1587096924886
# Episode * 478 * Avg Reward is ==> -233.92352728137158
# Episode * 479 * Avg Reward is ==> -233.70262393321653
# Episode * 480 * Avg Reward is ==> -233.22007231187345
# Episode * 481 * Avg Reward is ==> -232.98960708788758
# Episode * 482 * Avg Reward is ==> -232.99557266652627
# Episode * 483 * Avg Reward is ==> -233.27732479648145
# Episode * 484 * Avg Reward is ==> -232.80606808171328
# Episode * 485 * Avg Reward is ==> -232.83843834350182
# Episode * 486 * Avg Reward is ==> -232.84204672440057
# Episode * 487 * Avg Reward is ==> -232.61176584422455
# Episode * 488 * Avg Reward is ==> -232.3982808664736
# Episode * 489 * Avg Reward is ==> -232.16375694118207
# Episode * 490 * Avg Reward is ==> -231.94616097377974
# Episode * 491 * Avg Reward is ==> -231.97032009317988
# Episode * 492 * Avg Reward is ==> -232.00885741017566
# Episode * 493 * Avg Reward is ==> -232.30445667360988
# Episode * 494 * Avg Reward is ==> -232.09325278770993
# Episode * 495 * Avg Reward is ==> -231.85996281525516
# Episode * 496 * Avg Reward is ==> -231.867997994668
# Episode * 497 * Avg Reward is ==> -231.91010708153405
# Episode * 498 * Avg Reward is ==> -231.45074248100036
# Episode * 499 * Avg Reward is ==> -231.22484646987516
# '\nAfter 100 episodes:\n\n![after_img](https://i.imgur.com/eEH8Cz6.gif)\n'
